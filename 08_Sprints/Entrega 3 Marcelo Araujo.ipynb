# %% [markdown]
# Atividade 3 programacao em R

# %%
dados <- read.csv("movie.csv")

# %%
View (dados)
# Out:
#       movieId title
# 1      1      Toy Story (1995)
# 2      2      Jumanji (1995)
# 3      3      Grumpier Old Men (1995)
# 4      4      Waiting to Exhale (1995)
# 5      5      Father of the Bride Part II (1995)
# 6      6      Heat (1995)
# 7      7      Sabrina (1995)
# 8      8      Tom and Huck (1995)
# 9      9      Sudden Death (1995)
# 10    10      GoldenEye (1995)
# 11    11      American President, The (1995)
# 12    12      Dracula: Dead and Loving It (1995)
# 13    13      Balto (1995)
# 14    14      Nixon (1995)
# 15    15      Cutthroat Island (1995)
# 16    16      Casino (1995)
# 17    17      Sense and Sensibility (1995)
# 18    18      Four Rooms (1995)
# 19    19      Ace Ventura: When Nature Calls (1995)
# 20    20      Money Train (1995)
# 21    21      Get Shorty (1995)
# 22    22      Copycat (1995)
# 23    23      Assassins (1995)
# 24    24      Powder (1995)
# 25    25      Leaving Las Vegas (1995)
# 26    26      Othello (1995)
# ...

# %%
#Filtrar os filmes que contenham a palavra drama no titulo
filmes_nomedrama <- subset(dados, grepl("Drama", title))
print(filmes_nomedrama)
# Out:
#       movieId                                       title                genres
# 7205     7316 Confessions of a Teenage Drama Queen (2004)                Comedy
# 15413   78583                            Drama/Mex (2006)                 Drama
# 16887   85387     Chang: A Drama of the Wilderness (1927) Adventure|Documentary

# %%
#Filtrar os filmes de genero Guerra
filmes_guerra <- subset(dados, grepl("War", genres))

View(filmes_guerra)
# Out:
#       movieId
# 41     41
# 73     73
# 109   110
# 150   151
# 154   155
# 156   157
# 160   161
# 213   214
# 264   266
# 333   336
# 337   340
# 353   356
# 386   389
# 462   465
# 463   466
# 470   473
# 524   527
# 626   632
# 640   647
# 658   665
# 659   666
# 678   688
# 738   750
# 748   760
# 765   777
# 808   822
# 881   897
# 904   920
# 909   925
# 930   946
# ⋮     ⋮
# 25861 122756
# 25892 122950
# 25899 123113
# 25913 123219
# 25926 123337
# 25929 123353
# 25961 123669
# 26000 124352
# 26009 124450
# 26104 125523
# 26141 125786
# 26261 126126
# 26325 126416
# 26332 126430
# 26405 126947
# 26436 127011
# 26468 127076
# 26548 127256
# 26584 127441
# 26606 127622
# 26607 127626
# 26666 128301
# 26960 129555
# 27056 130036
# 27087 130328
# 27088 130338
# 27098 130382
# 27119 130474
# 27245 131138
# 27258 131164
#       title
# 41    Richard III (1995)
# 73    Misérables, Les (1995)
# 109   Braveheart (1995)
# 150   Rob Roy (1995)
# 154   Beyond Rangoon (1995)
# ...

# %%
# Filtrar os filmes de genero Guerra ralizados no ano de 1992
dados_1992 <- subset(filmes_guerra, grepl("\\(1992\\)", title))
View(dados_1992)
# Out:
#       movieId title
# 808      822  Hedd Wyn (1992)
# 1376    1408  Last of the Mohicans, The (1992)
# 6914    7025  Midnight Clear, A (1992)
# 7901    8582  Manufacturing Consent: Noam Chomsky and the Media (1992)
# 9056   26791  Shining Through (1992)
# 9724   31547  Lessons of Darkness (Lektionen in Finsternis) (1992)
# 15901  80650  Diên Biên Phú (1992)
# 20740 101514  Ungentlemanly Act, An (1992)
#       genres
# 808   Drama|Romance|War
# 1376  Action|Romance|War|Western
# 6914  Drama|War
# 7901  Documentary|War
# 9056  Drama|Romance|Thriller|War
# 9724  Documentary|War
# 15901 Drama|War
# 20740 Action|Documentary|Drama|War

# %% [markdown]
# Relatório:
# Foi realizado o filtro de filmes que contenham a palavra drama no titulo.
# (3 resultados)
# Posteriormente foi realizado um filtro de filmes de genero War
# (1194 resultados)
# A partir dessa análise foi realizado um segundo filtro para listar apenas os filmes de genero War realizados no ano de 1992
# (8 resultados)
# Os resultados foram apresentados a partir do comando View.
